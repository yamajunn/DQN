# %%
# import cv2
# import numpy as np
# import pyautogui

# # 画面の幅と高さを取得
# screen_width, screen_height = pyautogui.size()

# image_X = 300
# image_Y = 200

# while True:
#     # 画面をキャプチャ
#     screenshot = np.array(pyautogui.screenshot())

#     # 画像をリサイズしてグレースケールに変換
#     resized_image = cv2.resize(cv2.cvtColor(screenshot, cv2.COLOR_RGB2GRAY), (image_X, image_Y))

#     # マウスカーソルの座標を取得
#     x, y = pyautogui.position()

#     # 画像サイズと画面サイズの比率を計算
#     ratio_x = image_X / screen_width
#     ratio_y = image_Y / screen_height

#     # マウスカーソルの座標を画像の座標系に変換
#     x_image = int(x * ratio_x)
#     y_image = int(y * ratio_y)

#     # マウスカーソルを描画
#     cv2.circle(resized_image, (x_image, y_image), 1, (50, 50, 50), -1)

#     # 状態として使用する画像を準備
#     state = resized_image.flatten()

#     # 画面を表示
#     cv2.imshow("Screen", resized_image)

#     # キー入力を待機
#     if cv2.waitKey(1) == ord("q"):
#         break

# cv2.destroyAllWindows()

# %%
# import tkinter as tk
# import random

# # 報酬の初期値
# reward = 0

# # 報酬を与える関数
# def give_reward():
#     global reward
#     reward += 1  # 報酬をインクリメント
#     print("Reward:", reward)

# # ウィンドウを作成
# window = tk.Tk()
# window.title("Button Example")

# # 画面の幅と高さを取得
# screen_width = window.winfo_screenwidth()
# screen_height = window.winfo_screenheight()

# # ボタンを作成
# button = tk.Button(window, text="Click Me!", command=give_reward)

# # ボタンをウィンドウの右半分に配置
# button.place(x=screen_width // 2, y=0, relwidth=0.5, relheight=1, anchor="nw")

# # ウィンドウを表示
# window.mainloop()

# %%
import cv2
import numpy as np
import pyautogui
import tensorflow as tf
import tkinter as tk

# カーソルを左端に移動
pyautogui.moveTo(0, pyautogui.position().y)

# DQNの定義
class DQN(tf.keras.Model):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = tf.keras.layers.Dense(24, activation='relu')
        self.fc2 = tf.keras.layers.Dense(24, activation='relu')
        self.fc3 = tf.keras.layers.Dense(action_size, activation='linear')

    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        return self.fc3(x)

# DQNのパラメータ
state_size = 300 * 200  # 画像サイズ
action_size = 2  # 行動の数（例：左に移動、右に移動）

# DQNモデルの生成
model = DQN(state_size, action_size)

# ウィンドウを作成
window = tk.Tk()
window.title("Button Example")

# 画面の幅と高さを取得
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()

# ボタンを作成
button = tk.Button(window, text="Click Me!")

# ボタンをウィンドウの右半分に配置
button.place(x=screen_width // 2, y=0, relwidth=0.5, relheight=1, anchor="nw")

# ウィンドウを表示
window.mainloop()

# 画面の幅と高さを取得
screen_width, screen_height = pyautogui.size()

while True:
    # 画面をキャプチャ
    screenshot = np.array(pyautogui.screenshot())

    # 画像をリサイズしてグレースケールに変換
    resized_image = cv2.resize(cv2.cvtColor(screenshot, cv2.COLOR_RGB2GRAY), (300, 200))

    # 状態として使用する画像を準備
    state = resized_image.flatten()

    # DQNにより行動を決定
    action = model.predict(state)

    # DQNの出力に基づいてカーソルを移動させる
    if action == 0:
        pyautogui.move(-10, 0)  # 左に移動
    else:
        pyautogui.move(10, 0)  # 右に移動
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 61
#      58 state = resized_image.flatten()
#      60 # DQNにより行動を決定
# ---> 61 action = model.predict(state)
#      63 # DQNの出力に基づいてカーソルを移動させる
#      64 if action == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In [19], line 19, in DQN.call(self, x)
#      18 def call(self, x):
# ---> 19     x = self.fc1(x)
#      20     x = self.fc2(x)
#      21     return self.fc3(x)
#
# ValueError: Exception encountered when calling DQN.call().
#
# Input 0 of layer "dense_18" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (32,)
#
# Arguments received by DQN.call():
#   • x=tf.Tensor(shape=(32,), dtype=uint8)
# 現在のセルまたは前のセルでコードを実行中に、カーネル (Kernel) がクラッシュしました。
#
# エラーの原因を特定するには、セル内のコードを確認してください。
#
# 詳細については<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a>をクリックします。
#
# 詳細については、Jupyter <a href='command:jupyter.viewOutput'>ログ</a> を参照してください。
